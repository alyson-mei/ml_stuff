# %% [markdown]
# <a href="https://colab.research.google.com/github/alyson-mei/ml_stuff/blob/beta/word2vec.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Setup

# %%
# !pip install --upgrade nltk bokeh umap-learn
# Out:
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (3.9.1)
# Requirement already satisfied: bokeh in /usr/local/lib/python3.10/dist-packages (3.6.2)
# Collecting umap-learn
#   Downloading umap_learn-0.5.7-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk) (2024.11.6)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk) (4.67.1)
# Requirement already satisfied: Jinja2>=2.9 in /usr/local/lib/python3.10/dist-packages (from bokeh) (3.1.4)
# Requirement already satisfied: contourpy>=1.2 in /usr/local/lib/python3.10/dist-packages (from bokeh) (1.3.1)
# Requirement already satisfied: numpy>=1.16 in /usr/local/lib/python3.10/dist-packages (from bokeh) (1.26.4)
# Requirement already satisfied: packaging>=16.8 in /usr/local/lib/python3.10/dist-packages (from bokeh) (24.2)
# Requirement already satisfied: pandas>=1.2 in /usr/local/lib/python3.10/dist-packages (from bokeh) (2.2.2)
# Requirement already satisfied: pillow>=7.1.0 in /usr/local/lib/python3.10/dist-packages (from bokeh) (11.0.0)
# Requirement already satisfied: PyYAML>=3.10 in /usr/local/lib/python3.10/dist-packages (from bokeh) (6.0.2)
# Requirement already satisfied: tornado>=6.2 in /usr/local/lib/python3.10/dist-packages (from bokeh) (6.3.3)
# Requirement already satisfied: xyzservices>=2021.09.1 in /usr/local/lib/python3.10/dist-packages (from bokeh) (2024.9.0)
# Requirement already satisfied: scipy>=1.3.1 in /usr/local/lib/python3.10/dist-packages (from umap-learn) (1.13.1)
# Requirement already satisfied: scikit-learn>=0.22 in /usr/local/lib/python3.10/dist-packages (from umap-learn) (1.6.0)
# Requirement already satisfied: numba>=0.51.2 in /usr/local/lib/python3.10/dist-packages (from umap-learn) (0.60.0)
# Collecting pynndescent>=0.5 (from umap-learn)
#   Downloading pynndescent-0.5.13-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from Jinja2>=2.9->bokeh) (3.0.2)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba>=0.51.2->umap-learn) (0.43.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.2->bokeh) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.2->bokeh) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.2->bokeh) (2024.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.22->umap-learn) (3.5.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas>=1.2->bokeh) (1.17.0)
# Downloading umap_learn-0.5.7-py3-none-any.whl (88 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.8/88.8 kB 6.7 MB/s eta 0:00:00
# Downloading pynndescent-0.5.13-py3-none-any.whl (56 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.9/56.9 kB 5.0 MB/s eta 0:00:00
# Installing collected packages: pynndescent, umap-learn
# Successfully installed pynndescent-0.5.13 umap-learn-0.5.7

# %%
import itertools
import random
import string
from collections import Counter
from itertools import chain

import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.autograd as autograd
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import umap
from IPython.display import clear_output
from matplotlib import pyplot as plt
from nltk.tokenize import WordPunctTokenizer
from torch.optim.lr_scheduler import ReduceLROnPlateau, StepLR
from tqdm.auto import tqdm as tqdma

# %%
MIN_COUNT = 5
WINDOW_RADIUS = 5

BATCH_SIZE = 2048
SIZE = 10
NUM_NEGATIVES = 1
N_EPOCHS = 50

DEVICE = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")

# %%
def softmax(x, T = 0.5):
    exp = np.exp((x - max(x))/T)
    return x/np.sum(x)

# %%
# download the data:
# !wget https://www.dropbox.com/s/obaitrix9jyu84r/quora.txt?dl=1 -O ./quora.txt -nc
# alternative download link: https://yadi.sk/i/BPQrUu1NaTduEw
# Out:
# --2025-01-04 10:03:45--  https://www.dropbox.com/s/obaitrix9jyu84r/quora.txt?dl=1
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.2.18, 2620:100:6017:18::a27d:212
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.2.18|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://www.dropbox.com/scl/fi/p0t2dw6oqs6oxpd6zz534/quora.txt?rlkey=bjupppwua4zmd4elz8octecy9&dl=1 [following]
# --2025-01-04 10:03:45--  https://www.dropbox.com/scl/fi/p0t2dw6oqs6oxpd6zz534/quora.txt?rlkey=bjupppwua4zmd4elz8octecy9&dl=1
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc7efdf7583a08418b62e30727c8.dl.dropboxusercontent.com/cd/0/inline/ChiF_Y3l5pMOM5HyfMf2x4v-MTLIzi7df0BKv7sdjgtl_d_fVN6i1-27VrB0L_v3bGaT-VaDKXjRaFzBRK58UWh4O1VhR3_GCrv3ouvz-emqV6tZJPl8gtKNh0oDNnIxj8U/file?dl=1# [following]
# --2025-01-04 10:03:46--  https://uc7efdf7583a08418b62e30727c8.dl.dropboxusercontent.com/cd/0/inline/ChiF_Y3l5pMOM5HyfMf2x4v-MTLIzi7df0BKv7sdjgtl_d_fVN6i1-27VrB0L_v3bGaT-VaDKXjRaFzBRK58UWh4O1VhR3_GCrv3ouvz-emqV6tZJPl8gtKNh0oDNnIxj8U/file?dl=1
# Resolving uc7efdf7583a08418b62e30727c8.dl.dropboxusercontent.com (uc7efdf7583a08418b62e30727c8.dl.dropboxusercontent.com)... 162.125.2.15, 2620:100:6017:15::a27d:20f
# Connecting to uc7efdf7583a08418b62e30727c8.dl.dropboxusercontent.com (uc7efdf7583a08418b62e30727c8.dl.dropboxusercontent.com)|162.125.2.15|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 33813903 (32M) [application/binary]
# Saving to: ‘./quora.txt’
#
# ./quora.txt         100%[===================>]  32.25M  64.3MB/s    in 0.5s
#
# 2025-01-04 10:03:46 (64.3 MB/s) - ‘./quora.txt’ saved [33813903/33813903]

# %%
data = list(open("./quora.txt", encoding="utf-8"))
data[50]
# Out:
# "What TV shows or books help you read people's body language?\n"

# %% [markdown]
# ## Tokenization

# %%
tokenizer = WordPunctTokenizer()

print(tokenizer.tokenize(data[50]))
# Out:
# ['What', 'TV', 'shows', 'or', 'books', 'help', 'you', 'read', 'people', "'", 's', 'body', 'language', '?']

# %%
data_tok = [
    tokenizer.tokenize(
        line.translate(str.maketrans("", "", string.punctuation)).lower()
    )
    for line in data
]
data_tok = [x for x in data_tok if len(x) >= 3]

# %%
vocabulary_with_counter = Counter(chain.from_iterable(data_tok))

word_count_dict = dict()
for word, counter in vocabulary_with_counter.items():
    if counter >= MIN_COUNT:
        word_count_dict[word] = counter

vocabulary = set(word_count_dict.keys())
del vocabulary_with_counter

NUM_WORDS = len(vocabulary)

# %%
word_to_index = {word: index for index, word in enumerate(vocabulary)}
index_to_word = {index: word for word, index in word_to_index.items()}

# %%
data = {i: {} for i in range(NUM_WORDS)}

for text in tqdma(data_tok):
    for i, central_word in enumerate(text):
        context_indices = range(max(0, i -  WINDOW_RADIUS), min(i + WINDOW_RADIUS, len(text)))
        for j in context_indices:
            if j == i:
                continue
            context_word = text[j]
            if central_word in vocabulary and context_word in vocabulary and central_word != context_word:
                central_idx = word_to_index[central_word]
                context_idx = word_to_index[context_word]
                if context_idx not in data[central_idx]:
                    data[central_idx][context_idx] = 1
                else:
                    data[central_idx][context_idx] += 1
# Out:
#   0%|          | 0/537174 [00:00<?, ?it/s]

# %% [markdown]
# ## Subsampling
#
# Probability of dropping a word based on its frequency
#  $f(w)$:
#
# $$
# P_\text{drop}(w)= 1 - \textrm{min}\left(1, \sqrt{\frac{t}{f(w)}}\right)
# $$

# %%
def subsample_frequent_words(word_count_dict, threshold=1e-5):
    total_words = sum(word_count_dict.values())

    total_words = sum(word_count_dict.values())
    keep_prob_dict = {
        word: np.sqrt(min(1., threshold / ((word_count_dict[word] / total_words)))) for word in word_count_dict.keys()
    }

    return keep_prob_dict

# %%
keep_prob_dict = subsample_frequent_words(word_count_dict)
assert keep_prob_dict.keys() == word_count_dict.keys()

# %%
keep_prob_array = np.array(
    [keep_prob_dict[index_to_word[idx]] for idx in range(len(word_to_index))]
)

keep_prob_array /= np.sum(keep_prob_array)

data_val = []
data_id = []

for i in tqdma(range(NUM_WORDS)):
    keys = np.array(list(data[i].keys()))
    values = np.array(list(data[i].values())) * keep_prob_array[keys]
    argsort = np.argsort(np.array(values))[-SIZE:]
    if len(values) >= SIZE:
        new_values = softmax(np.array(values)[argsort])
        data_val.append(new_values)
        data_id.append(np.array(keys)[argsort])
    else:
        new_values = np.concatenate((softmax(np.array(values)[argsort]), np.zeros(SIZE - len(values))))
        new_keys = np.concatenate((keys, np.random.randint(low = 0, high = NUM_WORDS, size = SIZE - len(values))))
        data_val.append(new_values)
        data_id.append(new_keys)

data_val = torch.tensor(data_val).type(torch.float32)
data_id = torch.tensor(data_id)
keep_prob_array = torch.tensor(keep_prob_array)
# Out:
#   0%|          | 0/28546 [00:00<?, ?it/s]
# <ipython-input-16-70701edbee76>:24: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at ../torch/csrc/utils/tensor_new.cpp:278.)
#   data_val = torch.tensor(data_val).type(torch.float32)

# %% [markdown]
# ## Negative sampling
# Probability of using a word as a negative sample:
#
# $$
# P_n(w) = \frac{f(w)^{3/4}}{Z}
# $$

# %%
def get_negative_sampling_prob(word_count_dict):
    total_words = sum(word_count_dict.values())

    negative_sampling_prob_dict = {
        word: (word_count_dict[word]/total_words)**(3/4) for word in word_count_dict.keys()
    }
    Z = sum(negative_sampling_prob_dict.values())
    negative_sampling_prob_dict = {
        word: negative_sampling_prob_dict[word]/Z for word in negative_sampling_prob_dict.keys()
    }

    return negative_sampling_prob_dict

# %%
negative_sampling_prob_dict = get_negative_sampling_prob(word_count_dict)
assert negative_sampling_prob_dict.keys() == negative_sampling_prob_dict.keys()
assert np.allclose(sum(negative_sampling_prob_dict.values()), 1)

negative_sampling_prob_array = np.array(
    [
        negative_sampling_prob_dict[index_to_word[idx]]
        for idx in range(len(word_to_index))
    ]
)

# %% [markdown]
# ## Some tests

# %%
word_idx = word_to_index['python']

for idx in data_id[word_idx]:
    print(index_to_word[idx.item()])
# Out:
# programming
# php
# scraping
# r
# learning
# script
# django
# java
# ruby
# learn

# %%
center_id = torch.arange(4)
context_id = data_id[center_id]

center_embeddings = nn.Embedding(NUM_WORDS, 8)
context_embeddings = nn.Embedding(NUM_WORDS, 8)

center_embeds = center_embeddings(center_id)
context_embeds = context_embeddings(context_id)
weights = data_val[center_id].type(torch.float32)

cos_sim = F.cosine_similarity(center_embeds.unsqueeze(1).expand(4, SIZE, 8), context_embeds, dim = 2)
score = torch.bmm(cos_sim.unsqueeze(1), weights.unsqueeze(2)).squeeze()
score
# Out:
# tensor([ 0.2547,  0.0056,  0.0667, -0.1229], grad_fn=<SqueezeBackward0>)

# %% [markdown]
# ## SkipGramModel

# %% [markdown]
# ### Model and train

# %%
class SkipGramModel(nn.Module):
    def __init__(self, vocab_size = NUM_WORDS, embedding_dim = 64):
        super().__init__()
        self.center_embeddings = nn.Embedding(vocab_size, embedding_dim)
        self.context_embeddings = nn.Embedding(vocab_size, embedding_dim)
        self.cos_sim = None
        self.weights = None

    def forward(self, center_id, context_id): # center words from batch choice, context words from data_id
        center_embeds = self.center_embeddings(center_id)
        context_embeds = self.context_embeddings(context_id)
        self.weights = data_val[center_id].type(torch.float32)

        self.cos_sim = F.cosine_similarity(center_embeds.unsqueeze(1).expand(context_embeds.shape), context_embeds, dim = 2)
        score = torch.bmm(self.cos_sim.unsqueeze(1), self.weights.unsqueeze(2)).squeeze()

        return score

# %%
batch_center = torch.arange(BATCH_SIZE)
batch_context = data_id[batch_center]
model = SkipGramModel(NUM_WORDS, 16)
model(batch_center, batch_context)
# Out:
# tensor([-0.0666,  0.0075,  0.1176,  ...,  0.1354, -0.0638, -0.1076],
#        grad_fn=<SqueezeBackward0>)

# %%
def get_word_vector(word, embedding_matrix, word_to_index=word_to_index):
    return embedding_matrix[word_to_index[word]]

# %%
def find_nearest(word, embedding_matrix, word_to_index=word_to_index, k=10):
    word_vector = get_word_vector(word, embedding_matrix)[None, :]
    dists = F.cosine_similarity(embedding_matrix, word_vector)
    index_sorted = torch.argsort(dists)
    top_k = index_sorted[-k:]
    return [(index_to_word[x], dists[x].item()) for x in top_k.numpy()]

# %%
def train_skipgram(
    model,
    data_id,
    data_val,
    word_to_index,
    optimizer,
    lr_scheduler,
    n_epochs = N_EPOCHS,
    device = DEVICE,
    batch_size = BATCH_SIZE,
    num_negatives = NUM_NEGATIVES
):

    pos_labels = torch.ones(batch_size).to(device)
    loss_history = []

    for epoch in tqdma(range(n_epochs)):
        for i in range(0, NUM_WORDS - batch_size, batch_size):
            center_id = torch.multinomial(keep_prob_array, batch_size)
            context_id = data_id[center_id].to(device)

            optimizer.zero_grad()
            scores = model(center_id, context_id)

            loss = criterion(scores, pos_labels)

            loss.backward()
            optimizer.step()

            loss_history.append(loss.item())
            lr_scheduler.step(loss_history[-1])

        print(
            f"Epoch {epoch}, Loss: {np.mean(loss_history[- NUM_WORDS // batch_size:])}, learning rate: {lr_scheduler._last_lr}"
        )
        model.eval()

        with torch.no_grad():
            embedding_matrix_context = model.context_embeddings.weight
            print(f'Nearest to "python": ')
            print(find_nearest("python", embedding_matrix_context, k = 10))

            similarity_1 = F.cosine_similarity(
                get_word_vector("iphone", embedding_matrix_context)[None, :],
                get_word_vector("apple", embedding_matrix_context)[None, :],
            )
            similarity_2 = F.cosine_similarity(
                get_word_vector("iphone", embedding_matrix_context)[None, :],
                get_word_vector("dell", embedding_matrix_context)[None, :],
            )
            print(f'"iphone" is closer to "apple" than to "dell": {(similarity_1 > similarity_2).item()}')
            similarity_1 = F.cosine_similarity(
                get_word_vector("windows", embedding_matrix_context)[None, :],
                get_word_vector("laptop", embedding_matrix_context)[None, :],
            )
            similarity_2 = F.cosine_similarity(
                get_word_vector("windows", embedding_matrix_context)[None, :],
                get_word_vector("macbook", embedding_matrix_context)[None, :],
            )
            print(f'"windows" is closer to "laptop" than to "macbook": {(similarity_1 > similarity_2).item()}')

            center_id = torch.tensor(word_to_index['python']).reshape(1).to(device)
            context_id = data_id[center_id].to(device)

            print(f'Score for "python" {model(center_id, context_id)}')
            print('Cosine similarities for "python" with top-SIZE words: ')
            print(f'{model.cos_sim} \n')

        model.train()

# %%
vocab_size = NUM_WORDS
embedding_dim = 64

model = SkipGramModel(vocab_size, embedding_dim).to(DEVICE)
optimizer = optim.Adam(model.parameters(), lr=5e-2)
lr_scheduler = ReduceLROnPlateau(optimizer, factor=0.9)
criterion = nn.BCEWithLogitsLoss()

# %%
batch_size = BATCH_SIZE
train_skipgram(
    model,
    data_id,
    data_val,
    word_to_index,
    optimizer,
    lr_scheduler,
    batch_size = batch_size
)
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]
# Epoch 0, Loss: 0.6784409605539762, learning rate: [0.05]
# Nearest to "python":
# [('luffy', 0.43478330969810486), ('normative', 0.4398637115955353), ('confuse', 0.44137993454933167), ('physiologically', 0.4416586458683014), ('hdmi', 0.4420633018016815), ('burmese', 0.44318726658821106), ('stalling', 0.4594016671180725), ('tom', 0.4599189758300781), ('ic', 0.4747101366519928), ('python', 1.0)]
# "iphone" is closer to "apple" than to "dell": False
# "windows" is closer to "laptop" than to "macbook": False
# Score for "python" 0.07131633907556534
# Cosine similarities for "python" with top-SIZE words:
# tensor([[ 0.0847,  0.0909,  0.1772,  0.0247,  0.1615,  0.1081,  0.1297,  0.0667,
#           0.0090, -0.0535]])
#
# Epoch 1, Loss: 0.6420469624655587, learning rate: [0.05]
# Nearest to "python":
# [('describing', 0.42232441902160645), ('hdmi', 0.4239504337310791), ('3k', 0.4270451068878174), ('confuse', 0.4344664514064789), ('physiologically', 0.4360431134700775), ('tom', 0.4394197165966034), ('normative', 0.45021697878837585), ('ic', 0.4560070037841797), ('stalling', 0.4677807092666626), ('python', 1.0)]
# "iphone" is closer to "apple" than to "dell": False
# "windows" is closer to "laptop" than to "macbook": False
# Score for "python" 0.057133711874485016
# Cosine similarities for "python" with top-SIZE words:
# tensor([[ 0.1039,  0.0970,  0.1222, -0.0003,  0.1412,  0.0507,  0.0977,  0.0664,
#          -0.0020, -0.0316]])
#
# Epoch 2, Loss: 0.6063276827335358, learning rate: [0.05]
# Nearest to "python":
# [('tom', 0.424681156873703), ('physiologically', 0.42673325538635254), ('ic', 0.42840510606765747), ('vertex', 0.43095701932907104), ('describing', 0.4310622215270996), ('3k', 0.44236135482788086), ('sweetened', 0.443837434053421), ('stalling', 0.45591625571250916), ('normative', 0.4631049335002899), ('python', 1.0000001192092896)]
# "iphone" is closer to "apple" than to "dell": False
# "windows" is closer to "laptop" than to "macbook": False
# Score for "python" 0.044825371354818344
# Cosine similarities for "python" with top-SIZE words:
# tensor([[ 0.1339,  0.0881,  0.0606, -0.0217,  0.1170,  0.0017,  0.0718,  0.0605,
#          -0.0064, -0.0018]])
#
# Epoch 3, Loss: 0.5758131146430969, learning rate: [0.05]
# Nearest to "python":
# [('ponds', 0.41376516222953796), ('describing', 0.4139060080051422), ('knocked', 0.41665101051330566), ('kailash', 0.424457848072052), ('horn', 0.43035969138145447), ('stalling', 0.4449380338191986), ('3k', 0.4481258690357208), ('sweetened', 0.44870951771736145), ('normative', 0.48537683486938477), ('python', 1.0)]
# "iphone" is closer to "apple" than to "dell": True
# "windows" is closer to "laptop" than to "macbook": False
# Score for "python" 0.050599824637174606
# Cosine similarities for "python" with top-SIZE words:
# tensor([[ 0.1847,  0.0783,  0.0235, -0.0430,  0.1058, -0.0273,  0.0701,  0.0815,
#           0.0080,  0.0508]])
#
# Epoch 4, Loss: 0.5513803788593837, learning rate: [0.05]
# Nearest to "python":
# [('brightest', 0.4252604842185974), ('3k', 0.42886850237846375), ('customer', 0.42899537086486816), ('kailash', 0.4350283741950989), ('horn', 0.43872570991516113), ('nonproliferation', 0.43927034735679626), ('muhammads', 0.4400516450405121), ('sweetened', 0.4410870671272278), ('normative', 0.48836201429367065), ('python', 1.0)]
# "iphone" is closer to "apple" than to "dell": True
# "windows" is closer to "laptop" than to "macbook": False
# Score for "python" 0.12613904476165771
# Cosine similarities for "python" with top-SIZE words:
# tensor([[0.2354, 0.1267, 0.0389, 0.0104, 0.1807, 0.0286, 0.1355, 0.1358, 0.1578,
#          0.1706]])
#
# Epoch 5, Loss: 0.5315430973257337, learning rate: [0.05]
# Nearest to "python":
# [('empiricism', 0.42373043298721313), ('horn', 0.43048352003097534), ('ponds', 0.4318930208683014), ('brightest', 0.436678409576416), ('followed', 0.4432051479816437), ('muhammads', 0.446799099445343), ('hearthstone', 0.45384931564331055), ('nonproliferation', 0.474779337644577), ('normative', 0.49188053607940674), ('python', 1.000000238418579)]
# "iphone" is closer to "apple" than to "dell": True
# "windows" is closer to "laptop" than to "macbook": False
# Score for "python" 0.15454983711242676
# Cosine similarities for "python" with top-SIZE words:
# tensor([[0.2602, 0.1615, 0.0327, 0.0455, 0.2033, 0.0507, 0.1554, 0.1437, 0.2145,
#          0.2190]])
#
# Epoch 6, Loss: 0.5160237976482936, learning rate: [0.05]
# Nearest to "python":
# [('odor', 0.4183952212333679), ('muhammads', 0.4207878112792969), ('brightest', 0.42374229431152344), ('millions', 0.42965590953826904), ('horn', 0.4397204518318176), ('followed', 0.4552137851715088), ('nonproliferation', 0.4654421806335449), ('normative', 0.4789053499698639), ('hearthstone', 0.48502427339553833), ('python', 1.0000001192092896)]
# "iphone" is closer to "apple" than to "dell": True
# "windows" is closer to "laptop" than to "macbook": False
# Score for "python" 0.159351646900177
# Cosine similarities for "python" with top-SIZE words:
# tensor([[0.2712, 0.1783, 0.0015, 0.0473, 0.1900, 0.0397, 0.1673, 0.1409, 0.2541,
#          0.2278]])
#
# Epoch 7, Loss: 0.5027278746877398, learning rate: [0.05]
# Nearest to "python":
# [('hemisphere', 0.4233875870704651), ('odor', 0.42451539635658264), ('loreal', 0.43082940578460693), ('millions', 0.4360445439815521), ('nonproliferation', 0.45110154151916504), ('horn', 0.45365890860557556), ('normative', 0.4657970666885376), ('followed', 0.4665079116821289), ('hearthstone', 0.5123723745346069), ('python', 1.0)]
# "iphone" is closer to "apple" than to "dell": True
# "windows" is closer to "laptop" than to "macbook": False
# Score for "python" 0.15457206964492798
# Cosine similarities for "python" with top-SIZE words:
# tensor([[ 0.2773,  0.1868, -0.0521,  0.0509,  0.1756,  0.0262,  0.1615,  0.1487,
#           0.2421,  0.2425]])
#
# Epoch 8, Loss: 0.4921618380716869, learning rate: [0.05]
# Nearest to "python":
# [('dodo', 0.428688108921051), ('steps', 0.4302090108394623), ('loreal', 0.43309497833251953), ('horn', 0.4338189959526062), ('clubs', 0.43781527876853943), ('nonproliferation', 0.4396347999572754), ('normative', 0.4490619897842407), ('followed', 0.4745919704437256), ('hearthstone', 0.5111872553825378), ('python', 1.0)]
# "iphone" is closer to "apple" than to "dell": True
# "windows" is closer to "laptop" than to "macbook": False
# Score for "python" 0.19532541930675507
# Cosine similarities for "python" with top-SIZE words:
# tensor([[ 0.3104,  0.2164, -0.0549,  0.0893,  0.1921,  0.0365,  0.2134,  0.2095,
#           0.3050,  0.3104]])
#
# Epoch 9, Loss: 0.48294047372681753, learning rate: [0.05]
# Nearest to "python":
# [('wa', 0.4295833110809326), ('nonproliferation', 0.4297676682472229), ('direction', 0.4316657781600952), ('loreal', 0.4362477958202362), ('muhammads', 0.43832001090049744), ('clubs', 0.44053998589515686), ('salaam', 0.44570571184158325), ('followed', 0.49166837334632874), ('hearthstone', 0.5044522285461426), ('python', 0.9999998211860657)]
# "iphone" is closer to "apple" than to "dell": True
# "windows" is closer to "laptop" than to "macbook": False
# Score for "python" 0.24801096320152283
# Cosine similarities for "python" with top-SIZE words:
# tensor([[ 0.3456,  0.2526, -0.0333,  0.1449,  0.2314,  0.0646,  0.2610,  0.2850,
#           0.3965,  0.3722]])
#
# Epoch 10, Loss: 0.475321426987648, learning rate: [0.05]
# Nearest to "python":
# [('loreal', 0.42422720789909363), ('direction', 0.4294613003730774), ('kaine', 0.4444921314716339), ('muhammads', 0.44855964183807373), ('fighter', 0.4487484395503998), ('clubs', 0.45127955079078674), ('salaam', 0.4557175040245056), ('followed', 0.49828946590423584), ('hearthstone', 0.503201425075531), ('python', 1.0)]
# "iphone" is closer to "apple" than to "dell": True
# "windows" is closer to "laptop" than to "macbook": False
# Score for "python" 0.2595391869544983
# Cosine similarities for "python" with top-SIZE words:
# tensor([[ 0.3670,  0.2846, -0.0257,  0.1627,  0.2145,  0.0686,  0.2717,  0.2892,
#           0.4289,  0.3789]])
#
# Epoch 11, Loss: 0.4672592878341675, learning rate: [0.05]
# Nearest to "python":
# [('challan', 0.43688729405403137), ('salaam', 0.43719273805618286), ('fighter', 0.44166651368141174), ('muhammads', 0.44359034299850464), ('steps', 0.45631319284439087), ('clubs', 0.46318233013153076), ('kaine', 0.474031925201416), ('followed', 0.4899391829967499), ('hearthstone', 0.506475567817688), ('python', 1.0)]
# "iphone" is closer to "apple" than to "dell": True
# "windows" is closer to "laptop" than to "macbook": False
# Score for "python" 0.2632213234901428
# Cosine similarities for "python" with top-SIZE words:
# tensor([[ 0.3858,  0.2965, -0.0219,  0.1690,  0.2054,  0.0816,  0.2687,  0.2674,
#           0.4500,  0.3822]])
#
# Epoch 12, Loss: 0.4608712834971292, learning rate: [0.05]
# Nearest to "python":
# [('jfk', 0.44236257672309875), ('challan', 0.4437572956085205), ('shell', 0.44603341817855835), ('clubs', 0.47320640087127686), ('small', 0.4784012734889984), ('followed', 0.4851628541946411), ('kaine', 0.4908781349658966), ('steps', 0.4912947416305542), ('hearthstone', 0.499167799949646), ('python', 1.0)]
# "iphone" is closer to "apple" than to "dell": True
# "windows" is closer to "laptop" than to "macbook": False
# Score for "python" 0.31681835651397705
# Cosine similarities for "python" with top-SIZE words:
# tensor([[ 0.4395,  0.3586, -0.0166,  0.2131,  0.2324,  0.1318,  0.3477,  0.3060,
#           0.5203,  0.4601]])
#
# Epoch 13, Loss: 0.4538887675319399, learning rate: [0.05]
# Nearest to "python":
# [('aws', 0.4685530662536621), ('connection', 0.46974241733551025), ('melania', 0.4718239903450012), ('followed', 0.48768728971481323), ('clubs', 0.4929367005825043), ('hearthstone', 0.49403220415115356), ('kaine', 0.5012668967247009), ('steps', 0.5013726353645325), ('small', 0.52064448595047), ('python', 1.0)]
# "iphone" is closer to "apple" than to "dell": True
# "windows" is closer to "laptop" than to "macbook": False
# Score for "python" 0.3590622842311859
# Cosine similarities for "python" with top-SIZE words:
# tensor([[ 0.4753,  0.4164, -0.0110,  0.2379,  0.2561,  0.1635,  0.4132,  0.3571,
#           0.5765,  0.5080]])
#
# Epoch 14, Loss: 0.4470278429133551, learning rate: [0.05]
# Nearest to "python":
# [('shell', 0.5010032057762146), ('followed', 0.5076547265052795), ('cats', 0.5085470676422119), ('run', 0.5118499398231506), ('melania', 0.5138133764266968), ('aws', 0.5139518976211548), ('clubs', 0.5254254937171936), ('steps', 0.5408352613449097), ('small', 0.5723552703857422), ('python', 1.0)]
# "iphone" is closer to "apple" than to "dell": True
# "windows" is closer to "laptop" than to "macbook": False
# Score for "python" 0.3690071702003479
# Cosine similarities for "python" with top-SIZE words:
# tensor([[ 0.4795,  0.4402, -0.0121,  0.2252,  0.2571,  0.1710,  0.4150,  0.3771,
#           0.6010,  0.5254]])
#
# Epoch 15, Loss: 0.4387105852365494, learning rate: [0.05]
# Nearest to "python":
# [('involved', 0.5304051637649536), ('aws', 0.5501655340194702), ('clubs', 0.5583324432373047), ('followed', 0.5595102906227112), ('cats', 0.5704802870750427), ('run', 0.5770096778869629), ('melania', 0.5776866674423218), ('steps', 0.5997856855392456), ('small', 0.6350100636482239), ('python', 1.0000001192092896)]
# "iphone" is closer to "apple" than to "dell": True
# "windows" is closer to "laptop" than to "macbook": False
# Score for "python" 0.3740297555923462
# Cosine similarities for "python" with top-SIZE words:
# tensor([[ 0.4895,  0.4610, -0.0130,  0.2259,  0.2682,  0.1704,  0.4166,  0.3815,
#           0.6120,  0.5227]])
#
# Epoch 16, Loss: 0.43030624091625214, learning rate: [0.05]
# Nearest to "python":
# [('adsense', 0.588618814945221), ('clubs', 0.5896633863449097), ('aws', 0.5929347276687622), ('followed', 0.597374677658081), ('cats', 0.6284119486808777), ('run', 0.630367636680603), ('melania', 0.6361989974975586), ('steps', 0.6504277586936951), ('small', 0.6930323839187622), ('python', 0.9999998807907104)]
# "iphone" is closer to "apple" than to "dell": True
# "windows" is closer to "laptop" than to "macbook": False
# Score for "python" 0.3857285976409912
# Cosine similarities for "python" with top-SIZE words:
# tensor([[0.5065, 0.4873, 0.0072, 0.2495, 0.2770, 0.1789, 0.4266, 0.3900, 0.6261,
#          0.5187]])
#
# Epoch 17, Loss: 0.4207442211253302, learning rate: [0.05]
# Nearest to "python":
# [('thats', 0.6417362093925476), ('adsense', 0.6462252140045166), ('aws', 0.6473784446716309), ('api', 0.6558828949928284), ('cats', 0.6615917682647705), ('run', 0.6718091368675232), ('melania', 0.6774101257324219), ('steps', 0.6852911710739136), ('small', 0.7331551313400269), ('python', 1.0000001192092896)]
# "iphone" is closer to "apple" than to "dell": True
# "windows" is closer to "laptop" than to "macbook": False
# Score for "python" 0.4775810241699219
# Cosine similarities for "python" with top-SIZE words:
# tensor([[0.5898, 0.5856, 0.0901, 0.3479, 0.3691, 0.2846, 0.5271, 0.4939, 0.7081,
#          0.5945]])
#
# Epoch 18, Loss: 0.4101026675530842, learning rate: [0.05]
# Nearest to "python":
# [('server', 0.7015771865844727), ('aws', 0.7018319368362427), ('developer', 0.7068567872047424), ('cats', 0.7091249227523804), ('api', 0.7189781069755554), ('melania', 0.7230246663093567), ('steps', 0.7274118065834045), ('run', 0.7307742834091187), ('small', 0.7791839838027954), ('python', 1.0)]
# "iphone" is closer to "apple" than to "dell": True
# "windows" is closer to "laptop" than to "macbook": False
# Score for "python" 0.5033223628997803
# Cosine similarities for "python" with top-SIZE words:
# tensor([[0.6037, 0.6217, 0.1366, 0.3680, 0.3854, 0.3255, 0.5596, 0.5075, 0.7322,
#          0.6145]])
#
# Epoch 19, Loss: 0.39902365633419584, learning rate: [0.05]
# Nearest to "python":
# [('state', 0.7609339952468872), ('cats', 0.7618449926376343), ('developer', 0.7620701789855957), ('involved', 0.7648069262504578), ('melania', 0.7722193002700806), ('run', 0.7827626466751099), ('api', 0.7896379828453064), ('steps', 0.7900124788284302), ('small', 0.8174647092819214), ('python', 1.0)]
# "iphone" is closer to "apple" than to "dell": True
# "windows" is closer to "laptop" than to "macbook": False
# Score for "python" 0.5123856067657471
# Cosine similarities for "python" with top-SIZE words:
# tensor([[0.6037, 0.6371, 0.1698, 0.3818, 0.3975, 0.3509, 0.5829, 0.4987, 0.7273,
#          0.6109]])
#
# Epoch 20, Loss: 0.38800850936344694, learning rate: [0.05]
# Nearest to "python":
# [('web', 0.808497428894043), ('c', 0.8096355199813843), ('client', 0.8109027743339539), ('melania', 0.8155316114425659), ('steps', 0.8232123255729675), ('developer', 0.823883593082428), ('run', 0.8298904895782471), ('api', 0.8400976657867432), ('small', 0.8428884148597717), ('python', 1.0)]
# "iphone" is closer to "apple" than to "dell": True
# "windows" is closer to "laptop" than to "macbook": False
# Score for "python" 0.509789228439331
# Cosine similarities for "python" with top-SIZE words:
# tensor([[0.5937, 0.6363, 0.1907, 0.3821, 0.4081, 0.3680, 0.5857, 0.4861, 0.7227,
#          0.5791]])
#
# Epoch 21, Loss: 0.37792186439037323, learning rate: [0.05]
# Nearest to "python":
# [('client', 0.8581410050392151), ('web', 0.8596261739730835), ('setup', 0.8621852993965149), ('c', 0.8649957180023193), ('java', 0.8670861721038818), ('developer', 0.8707015514373779), ('api', 0.8771759867668152), ('small', 0.8804701566696167), ('run', 0.8856821060180664), ('python', 0.9999999403953552)]
# "iphone" is closer to "apple" than to "dell": True
# "windows" is closer to "laptop" than to "macbook": False
# Score for "python" 0.6443387866020203
# Cosine similarities for "python" with top-SIZE words:
# tensor([[0.7031, 0.7337, 0.3659, 0.5401, 0.5823, 0.5448, 0.6867, 0.6489, 0.8035,
#          0.7070]])
#
# Epoch 22, Loss: 0.3683475447552545, learning rate: [0.05]
# Nearest to "python":
# [('into', 0.8923953771591187), ('c', 0.892996609210968), ('web', 0.8971860408782959), ('setup', 0.8993886113166809), ('api', 0.900437593460083), ('small', 0.9020726680755615), ('java', 0.9025797247886658), ('developer', 0.9081634879112244), ('run', 0.9130511283874512), ('python', 1.0000001192092896)]
# "iphone" is closer to "apple" than to "dell": True
# "windows" is closer to "laptop" than to "macbook": False
# Score for "python" 0.6786779761314392
# Cosine similarities for "python" with top-SIZE words:
# tensor([[0.7257, 0.7664, 0.4386, 0.5796, 0.6260, 0.5931, 0.7181, 0.6837, 0.8217,
#          0.7247]])
#
# Epoch 23, Loss: 0.3593081853219441, learning rate: [0.05]
# Nearest to "python":
# [('consequences', 0.9162611365318298), ('small', 0.9167843461036682), ('c', 0.9177404642105103), ('api', 0.920155942440033), ('setup', 0.9234606623649597), ('java', 0.9239729046821594), ('web', 0.9247832298278809), ('run', 0.9248347282409668), ('developer', 0.9333208203315735), ('python', 0.9999998807907104)]
# "iphone" is closer to "apple" than to "dell": True
# "windows" is closer to "laptop" than to "macbook": False
# Score for "python" 0.7563226222991943
# Cosine similarities for "python" with top-SIZE words:
# tensor([[0.7930, 0.8256, 0.5606, 0.6739, 0.7157, 0.6945, 0.7758, 0.7663, 0.8651,
#          0.8025]])
#
# Epoch 24, Loss: 0.35201458845819744, learning rate: [0.05]
# Nearest to "python":
# [('server', 0.9365044832229614), ('run', 0.9383893013000488), ('consequences', 0.9383931159973145), ('api', 0.939080536365509), ('c', 0.939323902130127), ('java', 0.9399552941322327), ('setup', 0.9430593252182007), ('web', 0.9437916278839111), ('developer', 0.9518213272094727), ('python', 1.0)]
# "iphone" is closer to "apple" than to "dell": True
# "windows" is closer to "laptop" than to "macbook": False
# Score for "python" 0.7847566604614258
# Cosine similarities for "python" with top-SIZE words:
# tensor([[0.8107, 0.8529, 0.6151, 0.7096, 0.7439, 0.7282, 0.8105, 0.7908, 0.8800,
#          0.8254]])
#
# Epoch 25, Loss: 0.3454335480928421, learning rate: [0.05]
# Nearest to "python":
# [('consequences', 0.951066255569458), ('learn', 0.9519616365432739), ('c', 0.9523855447769165), ('server', 0.9527498483657837), ('client', 0.9534238576889038), ('java', 0.9544148445129395), ('web', 0.9558882117271423), ('setup', 0.9579311609268188), ('developer', 0.9642032384872437), ('python', 1.0)]
# "iphone" is closer to "apple" than to "dell": True
# "windows" is closer to "laptop" than to "macbook": True
# Score for "python" 0.7895419597625732
# Cosine similarities for "python" with top-SIZE words:
# tensor([[0.8061, 0.8595, 0.6410, 0.7184, 0.7486, 0.7333, 0.8241, 0.7905, 0.8887,
#          0.8130]])
#
# Epoch 26, Loss: 0.3402773269585201, learning rate: [0.05]
# Nearest to "python":
# [('c', 0.9659730195999146), ('learn', 0.9663047194480896), ('client', 0.9669107794761658), ('aws', 0.9669186472892761), ('server', 0.9683108329772949), ('web', 0.9685004353523254), ('java', 0.9685747623443604), ('setup', 0.9712623357772827), ('developer', 0.9752522706985474), ('python', 1.0)]
# "iphone" is closer to "apple" than to "dell": True
# "windows" is closer to "laptop" than to "macbook": True
# Score for "python" 0.7911039590835571
# Cosine similarities for "python" with top-SIZE words:
# tensor([[0.8023, 0.8567, 0.6692, 0.7224, 0.7460, 0.7349, 0.8360, 0.7850, 0.8935,
#          0.8008]])
#
# Epoch 27, Loss: 0.33567942891802105, learning rate: [0.05]
# Nearest to "python":
# [('c', 0.9739111661911011), ('api', 0.9748048782348633), ('client', 0.9749471545219421), ('aws', 0.9764286875724792), ('server', 0.977131187915802), ('web', 0.9772168397903442), ('setup', 0.9778041243553162), ('java', 0.9780711531639099), ('developer', 0.9832689762115479), ('python', 1.0)]
# "iphone" is closer to "apple" than to "dell": True
# "windows" is closer to "laptop" than to "macbook": True
# Score for "python" 0.7898396253585815
# Cosine similarities for "python" with top-SIZE words:
# tensor([[0.7950, 0.8480, 0.6913, 0.7243, 0.7407, 0.7395, 0.8392, 0.7809, 0.8952,
#          0.7865]])
#
# Epoch 28, Loss: 0.3317411903824125, learning rate: [0.05]
# Nearest to "python":
# [('queries', 0.979383647441864), ('client', 0.9803394079208374), ('aws', 0.9806536436080933), ('api', 0.9807490706443787), ('web', 0.9821540117263794), ('setup', 0.9827685356140137), ('java', 0.9831311702728271), ('server', 0.9833201169967651), ('developer', 0.9879902005195618), ('python', 1.0)]
# "iphone" is closer to "apple" than to "dell": True
# "windows" is closer to "laptop" than to "macbook": False
# Score for "python" 0.7995538711547852
# Cosine similarities for "python" with top-SIZE words:
# tensor([[0.8051, 0.8472, 0.7151, 0.7386, 0.7566, 0.7574, 0.8440, 0.7917, 0.8976,
#          0.7911]])
#
# Epoch 29, Loss: 0.3286393178360803, learning rate: [0.05]
# Nearest to "python":
# [('using', 0.9847174286842346), ('queries', 0.9847806096076965), ('aws', 0.9848650097846985), ('consequences', 0.9850260019302368), ('useful', 0.9855338931083679), ('java', 0.9856873750686646), ('server', 0.9860828518867493), ('setup', 0.9871500730514526), ('developer', 0.9910638928413391), ('python', 0.9999999403953552)]
# "iphone" is closer to "apple" than to "dell": True
# "windows" is closer to "laptop" than to "macbook": False
# Score for "python" 0.864682137966156
# Cosine similarities for "python" with top-SIZE words:
# tensor([[0.8707, 0.8967, 0.8078, 0.8203, 0.8375, 0.8380, 0.8919, 0.8595, 0.9261,
#          0.8639]])
#
# Epoch 30, Loss: 0.3259248733520508, learning rate: [0.05]
# Nearest to "python":
# [('users', 0.9880797266960144), ('app', 0.9883780479431152), ('java', 0.9885224103927612), ('keywords', 0.9885482788085938), ('client', 0.988827645778656), ('useful', 0.9888899326324463), ('setup', 0.9892764091491699), ('server', 0.9896070957183838), ('developer', 0.9925174713134766), ('python', 0.9999998807907104)]
# "iphone" is closer to "apple" than to "dell": True
# "windows" is closer to "laptop" than to "macbook": False
# Score for "python" 0.877325713634491
# Cosine similarities for "python" with top-SIZE words:
# tensor([[0.8830, 0.9049, 0.8313, 0.8379, 0.8534, 0.8532, 0.9020, 0.8713, 0.9333,
#          0.8741]])
#
# Epoch 31, Loss: 0.32388498527663095, learning rate: [0.05]
# Nearest to "python":
# [('css', 0.9906773567199707), ('application', 0.9906790852546692), ('easy', 0.9908329248428345), ('setup', 0.9910318851470947), ('keywords', 0.9910531044006348), ('client', 0.9916406869888306), ('java', 0.99192214012146), ('server', 0.9927076101303101), ('developer', 0.9945024251937866), ('python', 1.0)]
# "iphone" is closer to "apple" than to "dell": True
# "windows" is closer to "laptop" than to "macbook": False
# Score for "python" 0.8782837986946106
# Cosine similarities for "python" with top-SIZE words:
# tensor([[0.8815, 0.9042, 0.8376, 0.8408, 0.8551, 0.8541, 0.9013, 0.8722, 0.9345,
#          0.8737]])
#
# Epoch 32, Loss: 0.3221769630908966, learning rate: [0.05]
# Nearest to "python":
# [('client', 0.9923862218856812), ('keywords', 0.9925221800804138), ('aws', 0.9926244616508484), ('application', 0.9926332235336304), ('css', 0.9927473068237305), ('setup', 0.99290931224823), ('java', 0.9944270849227905), ('server', 0.9947988986968994), ('developer', 0.9954373836517334), ('python', 1.0000001192092896)]
# "iphone" is closer to "apple" than to "dell": True
# "windows" is closer to "laptop" than to "macbook": False
# Score for "python" 0.8756333589553833
# Cosine similarities for "python" with top-SIZE words:
# tensor([[0.8747, 0.9013, 0.8412, 0.8395, 0.8537, 0.8528, 0.8953, 0.8690, 0.9315,
#          0.8708]])
#
# Epoch 33, Loss: 0.32063141252313343, learning rate: [0.05]
# Nearest to "python":
# [('servers', 0.9936015605926514), ('software', 0.9936296939849854), ('aws', 0.9939845204353333), ('application', 0.9940463304519653), ('css', 0.9943693280220032), ('setup', 0.9944020509719849), ('server', 0.9956173896789551), ('developer', 0.9956787824630737), ('java', 0.9959669709205627), ('python', 1.0)]
# "iphone" is closer to "apple" than to "dell": True
# "windows" is closer to "laptop" than to "macbook": True
# Score for "python" 0.8733611106872559
# Cosine similarities for "python" with top-SIZE words:
# tensor([[0.8702, 0.8969, 0.8432, 0.8373, 0.8517, 0.8518, 0.8908, 0.8680, 0.9289,
#          0.8684]])
#
# Epoch 34, Loss: 0.31939826692853657, learning rate: [0.05]
# Nearest to "python":
# [('aws', 0.9951679110527039), ('programmers', 0.9951854944229126), ('learn', 0.9953205585479736), ('css', 0.9954513311386108), ('application', 0.9955859184265137), ('setup', 0.9957329034805298), ('server', 0.9960857033729553), ('java', 0.9963715672492981), ('developer', 0.9965407252311707), ('python', 1.0)]
# "iphone" is closer to "apple" than to "dell": True
# "windows" is closer to "laptop" than to "macbook": True
# Score for "python" 0.8712368607521057
# Cosine similarities for "python" with top-SIZE words:
# tensor([[0.8679, 0.8927, 0.8454, 0.8370, 0.8511, 0.8513, 0.8876, 0.8658, 0.9255,
#          0.8640]])
#
# Epoch 35, Loss: 0.3184044637850353, learning rate: [0.05]
# Nearest to "python":
# [('api', 0.9963207244873047), ('useful', 0.9963405132293701), ('css', 0.9963769912719727), ('keywords', 0.9963995218276978), ('application', 0.9965112209320068), ('java', 0.9965741038322449), ('setup', 0.9967867136001587), ('server', 0.9969626665115356), ('developer', 0.9974038004875183), ('python', 1.0000001192092896)]
# "iphone" is closer to "apple" than to "dell": True
# "windows" is closer to "laptop" than to "macbook": True
# Score for "python" 0.8686078786849976
# Cosine similarities for "python" with top-SIZE words:
# tensor([[0.8660, 0.8886, 0.8457, 0.8376, 0.8511, 0.8498, 0.8833, 0.8648, 0.9202,
#          0.8581]])
#
# Epoch 36, Loss: 0.3175340188401086, learning rate: [0.05]
# Nearest to "python":
# [('client', 0.9969850778579712), ('useful', 0.9970287084579468), ('application', 0.997153639793396), ('api', 0.9972249865531921), ('keywords', 0.9973649382591248), ('setup', 0.9973658323287964), ('server', 0.9974473714828491), ('java', 0.9974792003631592), ('developer', 0.9980926513671875), ('python', 1.0)]
# "iphone" is closer to "apple" than to "dell": True
# "windows" is closer to "laptop" than to "macbook": False
# Score for "python" 0.8670594096183777
# Cosine similarities for "python" with top-SIZE words:
# tensor([[0.8643, 0.8855, 0.8440, 0.8381, 0.8480, 0.8490, 0.8861, 0.8622, 0.9172,
#          0.8557]])
#
# Epoch 37, Loss: 0.31691692982401165, learning rate: [0.05]
# Nearest to "python":
# [('useful', 0.997582197189331), ('application', 0.9976598024368286), ('client', 0.9977530837059021), ('server', 0.9977840185165405), ('keywords', 0.9978423714637756), ('api', 0.9979058504104614), ('setup', 0.9979299306869507), ('java', 0.9982170462608337), ('developer', 0.9983392953872681), ('python', 1.0)]
# "iphone" is closer to "apple" than to "dell": True
# "windows" is closer to "laptop" than to "macbook": False
# Score for "python" 0.8643709421157837
# Cosine similarities for "python" with top-SIZE words:
# tensor([[0.8610, 0.8827, 0.8423, 0.8380, 0.8458, 0.8455, 0.8846, 0.8575, 0.9122,
#          0.8544]])
#
# Epoch 38, Loss: 0.3162750516619001, learning rate: [0.05]
# Nearest to "python":
# [('keywords', 0.9981752634048462), ('application', 0.9981834888458252), ('client', 0.9982215762138367), ('server', 0.9982351064682007), ('java', 0.9982872605323792), ('programmers', 0.998308539390564), ('api', 0.9984352588653564), ('setup', 0.998512864112854), ('developer', 0.9985451698303223), ('python', 1.0)]
# "iphone" is closer to "apple" than to "dell": True
# "windows" is closer to "laptop" than to "macbook": False
# Score for "python" 0.917628824710846
# Cosine similarities for "python" with top-SIZE words:
# tensor([[0.9164, 0.9292, 0.9033, 0.8999, 0.9046, 0.9056, 0.9314, 0.9121, 0.9473,
#          0.9134]])
#
# Epoch 39, Loss: 0.31577347431864056, learning rate: [0.05]
# Nearest to "python":
# [('servers', 0.9982970952987671), ('client', 0.9983199834823608), ('application', 0.9983524084091187), ('java', 0.9984160661697388), ('programmers', 0.9984971880912781), ('api', 0.9985383749008179), ('server', 0.9986461997032166), ('setup', 0.9987186789512634), ('developer', 0.99881511926651), ('python', 1.0000001192092896)]
# "iphone" is closer to "apple" than to "dell": True
# "windows" is closer to "laptop" than to "macbook": False
# Score for "python" 0.9493362307548523
# Cosine similarities for "python" with top-SIZE words:
# tensor([[0.9490, 0.9577, 0.9397, 0.9368, 0.9402, 0.9415, 0.9590, 0.9449, 0.9680,
#          0.9477]])
#
# Epoch 40, Loss: 0.3153880408832005, learning rate: [0.05]
# Nearest to "python":
# [('keywords', 0.9986494779586792), ('java', 0.9986525774002075), ('client', 0.9986738562583923), ('api', 0.9986848831176758), ('servers', 0.998741626739502), ('programmers', 0.9987990856170654), ('setup', 0.9989063739776611), ('server', 0.9989641904830933), ('developer', 0.9991477131843567), ('python', 1.0)]
# "iphone" is closer to "apple" than to "dell": True
# "windows" is closer to "laptop" than to "macbook": False
# Score for "python" 0.9632699489593506
# Cosine similarities for "python" with top-SIZE words:
# tensor([[0.9631, 0.9705, 0.9568, 0.9532, 0.9572, 0.9580, 0.9707, 0.9600, 0.9763,
#          0.9611]])
#
# Epoch 41, Loss: 0.3150563005890165, learning rate: [0.05]
# Nearest to "python":
# [('keywords', 0.9988726377487183), ('client', 0.9988898634910583), ('apps', 0.9988929629325867), ('eclipse', 0.9989177584648132), ('aws', 0.9989184141159058), ('servers', 0.9989386796951294), ('setup', 0.9990863800048828), ('server', 0.9992448091506958), ('developer', 0.9993159770965576), ('python', 0.9999999403953552)]
# "iphone" is closer to "apple" than to "dell": True
# "windows" is closer to "laptop" than to "macbook": False
# Score for "python" 0.9652263522148132
# Cosine similarities for "python" with top-SIZE words:
# tensor([[0.9653, 0.9722, 0.9598, 0.9558, 0.9602, 0.9601, 0.9725, 0.9628, 0.9771,
#          0.9620]])
#
# Epoch 42, Loss: 0.3147694298199245, learning rate: [0.05]
# Nearest to "python":
# [('servers', 0.9990575909614563), ('queries', 0.9990619421005249), ('instance', 0.999075174331665), ('eclipse', 0.9991215467453003), ('setup', 0.9991768598556519), ('aws', 0.9992225170135498), ('java', 0.999298632144928), ('developer', 0.9993825554847717), ('server', 0.9993852972984314), ('python', 1.0)]
# "iphone" is closer to "apple" than to "dell": True
# "windows" is closer to "laptop" than to "macbook": True
# Score for "python" 0.9648855328559875
# Cosine similarities for "python" with top-SIZE words:
# tensor([[0.9648, 0.9711, 0.9601, 0.9563, 0.9599, 0.9596, 0.9713, 0.9633, 0.9767,
#          0.9614]])
#
# Epoch 43, Loss: 0.31457418629101347, learning rate: [0.05]
# Nearest to "python":
# [('setup', 0.999189555644989), ('frameworks', 0.9991898536682129), ('queries', 0.9992038011550903), ('keywords', 0.999241828918457), ('eclipse', 0.9992506504058838), ('aws', 0.9992945194244385), ('server', 0.9993585348129272), ('java', 0.999499499797821), ('developer', 0.9995254278182983), ('python', 1.0)]
# "iphone" is closer to "apple" than to "dell": True
# "windows" is closer to "laptop" than to "macbook": True
# Score for "python" 0.9642378091812134
# Cosine similarities for "python" with top-SIZE words:
# tensor([[0.9640, 0.9702, 0.9595, 0.9565, 0.9593, 0.9584, 0.9707, 0.9620, 0.9760,
#          0.9613]])
#
# Epoch 44, Loss: 0.3144148758479527, learning rate: [0.05]
# Nearest to "python":
# [('setup', 0.9993658065795898), ('apps', 0.9993830323219299), ('api', 0.9993934035301208), ('keywords', 0.9994337558746338), ('queries', 0.9994375109672546), ('aws', 0.9994707107543945), ('server', 0.9994930028915405), ('java', 0.999572217464447), ('developer', 0.9996725916862488), ('python', 0.9999999403953552)]
# "iphone" is closer to "apple" than to "dell": False
# "windows" is closer to "laptop" than to "macbook": True
# Score for "python" 0.9765457510948181
# Cosine similarities for "python" with top-SIZE words:
# tensor([[0.9761, 0.9809, 0.9732, 0.9711, 0.9730, 0.9729, 0.9806, 0.9750, 0.9844,
#          0.9751]])
#
# Epoch 45, Loss: 0.31422012405736105, learning rate: [0.05]
# Nearest to "python":
# [('api', 0.9995124340057373), ('queries', 0.9995171427726746), ('application', 0.9995205402374268), ('learn', 0.9995474815368652), ('keywords', 0.9995554685592651), ('server', 0.9995647668838501), ('aws', 0.9995920062065125), ('java', 0.9996364712715149), ('developer', 0.9997557401657104), ('python', 1.0000001192092896)]
# "iphone" is closer to "apple" than to "dell": True
# "windows" is closer to "laptop" than to "macbook": True
# Score for "python" 0.980154275894165
# Cosine similarities for "python" with top-SIZE words:
# tensor([[0.9798, 0.9838, 0.9775, 0.9758, 0.9772, 0.9776, 0.9832, 0.9787, 0.9865,
#          0.9789]])
#
# Epoch 46, Loss: 0.3140433451959065, learning rate: [0.045000000000000005]
# Nearest to "python":
# [('api', 0.999536395072937), ('frameworks', 0.9995371699333191), ('adsense', 0.9995447397232056), ('configure', 0.9995543956756592), ('eclipse', 0.9995657801628113), ('server', 0.9995676279067993), ('aws', 0.9996290802955627), ('java', 0.9996403455734253), ('developer', 0.9997535943984985), ('python', 1.0)]
# "iphone" is closer to "apple" than to "dell": True
# "windows" is closer to "laptop" than to "macbook": True
# Score for "python" 0.9803452491760254
# Cosine similarities for "python" with top-SIZE words:
# tensor([[0.9802, 0.9837, 0.9783, 0.9766, 0.9772, 0.9783, 0.9834, 0.9791, 0.9859,
#          0.9790]])
#
# Epoch 47, Loss: 0.3139407954045704, learning rate: [0.045000000000000005]
# Nearest to "python":
# [('adsense', 0.9996576309204102), ('queries', 0.9996703863143921), ('application', 0.999673068523407), ('api', 0.9996952414512634), ('eclipse', 0.9996964931488037), ('server', 0.9997037053108215), ('java', 0.9997453689575195), ('aws', 0.9997544288635254), ('developer', 0.9998162984848022), ('python', 1.0)]
# "iphone" is closer to "apple" than to "dell": True
# "windows" is closer to "laptop" than to "macbook": True
# Score for "python" 0.9821560382843018
# Cosine similarities for "python" with top-SIZE words:
# tensor([[0.9820, 0.9848, 0.9805, 0.9790, 0.9796, 0.9803, 0.9849, 0.9812, 0.9868,
#          0.9808]])
#
# Epoch 48, Loss: 0.3138430544308254, learning rate: [0.045000000000000005]
# Nearest to "python":
# [('developers', 0.9996740818023682), ('api', 0.999681830406189), ('frameworks', 0.9996996521949768), ('queries', 0.9997071027755737), ('eclipse', 0.9997328519821167), ('server', 0.9997400045394897), ('aws', 0.9997444152832031), ('developer', 0.9998210072517395), ('java', 0.9998316764831543), ('python', 1.0)]
# "iphone" is closer to "apple" than to "dell": True
# "windows" is closer to "laptop" than to "macbook": True
# Score for "python" 0.9879562258720398
# Cosine similarities for "python" with top-SIZE words:
# tensor([[0.9875, 0.9898, 0.9866, 0.9856, 0.9862, 0.9861, 0.9901, 0.9875, 0.9916,
#          0.9870]])
#
# Epoch 49, Loss: 0.31376547685691286, learning rate: [0.045000000000000005]
# Nearest to "python":
# [('database', 0.9997155666351318), ('developers', 0.9997214078903198), ('eclipse', 0.9997521638870239), ('queries', 0.9997551441192627), ('frameworks', 0.9997574090957642), ('developer', 0.9997648000717163), ('server', 0.9997810125350952), ('aws', 0.9997812509536743), ('java', 0.9998776316642761), ('python', 1.0000001192092896)]
# "iphone" is closer to "apple" than to "dell": True
# "windows" is closer to "laptop" than to "macbook": True
# Score for "python" 0.9890419840812683
# Cosine similarities for "python" with top-SIZE words:
# tensor([[0.9885, 0.9909, 0.9873, 0.9869, 0.9874, 0.9875, 0.9910, 0.9888, 0.9924,
#          0.9881]])

# %% [markdown]
# ### Eval

# %%
embedding_matrix_context = model.context_embeddings.weight

# %%
similarity_1 = F.cosine_similarity(
    get_word_vector("iphone", embedding_matrix_context)[None, :],
    get_word_vector("apple", embedding_matrix_context)[None, :],
)
similarity_2 = F.cosine_similarity(
    get_word_vector("iphone", embedding_matrix_context)[None, :],
    get_word_vector("dell", embedding_matrix_context)[None, :],
)
assert similarity_1 > similarity_2

# %%
similarity_1 = F.cosine_similarity(
    get_word_vector("windows", embedding_matrix_context)[None, :],
    get_word_vector("laptop", embedding_matrix_context)[None, :],
)
similarity_2 = F.cosine_similarity(
    get_word_vector("windows", embedding_matrix_context)[None, :],
    get_word_vector("macbook", embedding_matrix_context)[None, :],
)
assert similarity_1 > similarity_2

# %%
def find_nearest(word, embedding_matrix, word_to_index=word_to_index, k=10):
    word_vector = get_word_vector(word, embedding_matrix)[None, :]
    dists = F.cosine_similarity(embedding_matrix, word_vector)
    index_sorted = torch.argsort(dists)
    top_k = index_sorted[-k:]
    return [(index_to_word[x], dists[x].item()) for x in top_k.numpy()]

# %%
find_nearest("python", embedding_matrix_context, k = 10)
# Out:
# [('database', 0.9997155666351318),
#  ('developers', 0.9997214078903198),
#  ('eclipse', 0.9997521638870239),
#  ('queries', 0.9997551441192627),
#  ('frameworks', 0.9997574090957642),
#  ('developer', 0.9997648000717163),
#  ('server', 0.9997810125350952),
#  ('aws', 0.9997812509536743),
#  ('java', 0.9998776316642761),
#  ('python', 1.0000001192092896)]

# %%
find_nearest("iphone", embedding_matrix_context, k = 10)
# Out:
# [('android', 0.9993677139282227),
#  ('ios', 0.9993709325790405),
#  ('upgrade', 0.9993985891342163),
#  ('facetime', 0.9994360208511353),
#  ('update', 0.9994602799415588),
#  ('unlocked', 0.9994757175445557),
#  ('plus', 0.9994993209838867),
#  ('rooting', 0.9995481371879578),
#  ('6s', 0.9997088313102722),
#  ('iphone', 1.0)]

# %%
find_nearest("learn", embedding_matrix_context, k = 10)
# Out:
# [('editing', 0.999640941619873),
#  ('scratch', 0.9996446371078491),
#  ('data', 0.999656617641449),
#  ('tips', 0.9996582269668579),
#  ('amazon', 0.9996594190597534),
#  ('unix', 0.9996654987335205),
#  ('languages', 0.9996708035469055),
#  ('programmers', 0.9996929168701172),
#  ('programming', 0.9996968507766724),
#  ('learn', 1.0000001192092896)]

# %%
top_k = 5000
_top_words = sorted([x for x in word_count_dict.items()], key=lambda x: x[1])[
    -top_k - 100 : -100
]  # ignoring 100 most frequent words
top_words = [x[0] for x in _top_words]
del _top_words

word_embeddings = torch.cat(
    [embedding_matrix_context[word_to_index[x]][None, :] for x in top_words], dim=0
).detach().numpy()

# %%
import bokeh.models as bm
import bokeh.plotting as pl
from bokeh.io import output_notebook

output_notebook()


def draw_vectors(
    x,
    y,
    radius=10,
    alpha=0.25,
    color="blue",
    width=600,
    height=400,
    show=True,
    **kwargs,
):
    """draws an interactive plot for data points with auxilirary info on hover"""
    if isinstance(color, str):
        color = [color] * len(x)
    data_source = bm.ColumnDataSource({"x": x, "y": y, "color": color, **kwargs})

    fig = pl.figure(active_scroll="wheel_zoom", width=width, height=height)
    fig.scatter("x", "y", size=radius, color="color", alpha=alpha, source=data_source)

    fig.add_tools(bm.HoverTool(tooltips=[(key, "@" + key) for key in kwargs.keys()]))
    if show:
        pl.show(fig)
    return fig

# %%
embedding = umap.UMAP(n_neighbors=5).fit_transform(word_embeddings)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(

# %%
draw_vectors(embedding[:, 0], embedding[:, 1], token=top_words)
# Out:
#   <div id="d28e03ca-390e-4eb2-9c6e-f1481a97294b" data-root-id="p1208" style="display: contents;"></div>
# figure(id='p1208', ...)
